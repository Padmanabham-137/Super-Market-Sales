# %%
# Importing the libraries

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# Ignore harmless warnings 

import warnings 
warnings.filterwarnings("ignore")

# Set to display all the columns in dataset

pd.set_option("display.max_columns", None)

# To run sql queries on DataFrame


# !pip install pandasql
import pandasql as psql

# %%
# Load the Retail data

sms = pd.read_csv(r"C:\Users\Dell\Downloads\supermarket_sales - Sheet1.csv", header = 0)

# Copy to back-up files

sms_bk = sms.copy()

# Display first five claims data

sms.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#display last 5 records

sms.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
# display the datatypes of the dataset information

sms.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
#identify the missing values in the data set

sms.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#display the dataset information

sms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
#display the shape of the data

sms.shape
# Out:
# (1000, 17)

# %%
#displaying the outlier detection

Rating_UL = round(sms.Rating.mean() + 3 * sms.Rating.std(),3)
Rating_LL = round(sms.Rating.mean() - 3 * sms.Rating.std(),3)
sms = sms[(sms.Rating > Rating_LL) & (sms.Rating < Rating_UL)]
sms_bk = sms
sms.shape
# Out:
# (1000, 17)

# %%
#identify duplicate values with the data set

sms_dup = sms[sms.duplicated(keep='last')]

#display the duplicate records

sms_dup
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %%
#display the unique values of all the variables

sms.nunique()
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %%
# Display the 'Branch' value by count

sms['Branch'].value_counts()
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: count, dtype: int64

# %%
# Display the 'City' value by count

sms['City'].value_counts()
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
# Display the 'Customer type' value by count

sms['Customer type'].value_counts()
# Out:
# Customer type
# Member    501
# Normal    499
# Name: count, dtype: int64

# %%
# Display the 'Gender' value by count

sms['Gender'].value_counts()
# Out:
# Gender
# Female    501
# Male      499
# Name: count, dtype: int64

# %%
# Display the 'Product line' value by count

sms['Product line'].value_counts()
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %%
# Display the 'Date' value by count

sms['Date'].value_counts()
# Out:
# Date
# 2/7/2019     20
# 2/15/2019    19
# 3/14/2019    18
# 3/2/2019     18
# 1/8/2019     18
#              ..
# 1/4/2019      6
# 2/28/2019     6
# 2/21/2019     6
# 3/17/2019     6
# 2/1/2019      6
# Name: count, Length: 89, dtype: int64

# %%
# Display the 'Time' value by count

sms['Time'].value_counts()
# Out:
# Time
# 19:48    7
# 14:42    7
# 17:38    6
# 17:16    5
# 11:40    5
#         ..
# 13:26    1
# 11:17    1
# 14:57    1
# 17:53    1
# 19:12    1
# Name: count, Length: 506, dtype: int64

# %%
# Display the 'Payment' value by count

sms['Payment'].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
# Display the 'Rating' value by count

sms['Rating'].value_counts()
# Out:
# Rating
# 6.0     26
# 6.6     24
# 4.2     22
# 9.5     22
# 6.5     21
#         ..
# 4.0     11
# 5.3     11
# 8.3     11
# 4.6      8
# 10.0     5
# Name: count, Length: 61, dtype: int64

# %%
#use labelencoder for target variable

from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
sms['Branch']=LE.fit_transform(sms['Branch'])
sms['City']=LE.fit_transform(sms['City'])
sms['Customer type']=LE.fit_transform(sms['Customer type'])
sms['Gender']=LE.fit_transform(sms['Gender'])
sms['Product line']=LE.fit_transform(sms['Product line'])
sms['Date']=LE.fit_transform(sms['Date'])
sms['Time']=LE.fit_transform(sms['Time'])
sms['Payment']=LE.fit_transform(sms['Payment'])

# %%
# delete the test id

del sms['Invoice ID']

#display the dataset information

sms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   int32
#  1   City                     1000 non-null   int32
#  2   Customer type            1000 non-null   int32
#  3   Gender                   1000 non-null   int32
#  4   Product line             1000 non-null   int32
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Date                     1000 non-null   int32
#  10  Time                     1000 non-null   int32
#  11  Payment                  1000 non-null   int32
#  12  cogs                     1000 non-null   float64
#  13  gross margin percentage  1000 non-null   float64
# ...

# %%
# diplay descriptive  statistics

sms.describe()
# Out:
#             Branch         City  Customer type       Gender  Product line  \
# count  1000.000000  1000.000000    1000.000000  1000.000000   1000.000000
# mean      0.988000     1.008000       0.499000     0.499000      2.452000
# std       0.817633     0.820127       0.500249     0.500249      1.715412
# min       0.000000     0.000000       0.000000     0.000000      0.000000
# 25%       0.000000     0.000000       0.000000     0.000000      1.000000
# 50%       1.000000     1.000000       0.000000     0.000000      2.000000
# 75%       2.000000     2.000000       1.000000     1.000000      4.000000
# max       2.000000     2.000000       1.000000     1.000000      5.000000
#
#         Unit price     Quantity       Tax 5%        Total         Date  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749    44.582000
# std      26.494628     2.923431    11.708825   245.885335    25.894745
# ...

# %%
# identify the identify and target(dependent) variable

indepvar=[]
for col in sms.columns:
    if col !='Rating':
        indepvar.append(col)
targetvar='Rating'

x=sms[indepvar]
y=sms[targetvar]

# %%
# Split the data into train and test (random sampling)

from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Display the shape for train & test data

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((700, 15), (300, 15), (700,), (300,))

# %%
#scaling the features by using MinMaxScaler

from sklearn.preprocessing import MinMaxScaler

mmscaler = MinMaxScaler (feature_range=(0,1))

x_train = mmscaler.fit_transform(x_train)
x_train = pd.DataFrame(x_train)

x_test = mmscaler.fit_transform(x_test)
x_test = pd.DataFrame(x_test)

# %%
#compare with all regression/regressor

# %%
# loading the result file

RGRResults=pd.read_csv(r"C:\Users\Dell\Downloads\RGRResults.csv",header=0)
RGRResults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, Mean_Absolute_Error_MAE, Adj_R_Square, Root_Mean_Squared_Error_RMSE, Mean_Absolute_Percentage_Error_MAPE, Mean_Squared_Error_MSE, Root_Mean_Squared_Log_Error_RMSLE, R2_score]
# Index: []

# %%
# Build the Regression / Regressor models

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.svm import SVR

# Create objects of Regression / Regressor models with default hyper-parameters

ModelMLR = LinearRegression()
ModelDCR = DecisionTreeRegressor()
ModelRFR = RandomForestRegressor()
ModelETR = ExtraTreesRegressor()
ModelKNN = KNeighborsRegressor(n_neighbors=5)
ModelBRR = BayesianRidge()
ModelSVR = SVR()

# Evalution matrix for all the algorithms

#MM = [ModelMLR, ModelDCR, ModelRFR, ModelETR, ModelKNN, ModelBRR, ModelSVR] 
MM = [ModelMLR, ModelDCR, ModelRFR, ModelETR, ModelKNN, ModelBRR, ModelSVR]

for models in MM:
    
    # Fit the model with train data
    
    models.fit(x_train, y_train)
    
    # Predict the model with test data

    y_pred = models.predict(x_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # Evaluation metrics for Regression analysis

    from sklearn import metrics

    print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, y_pred),3))  
    print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, y_pred),3))  
    print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),3))
    print('R2_score:', round(metrics.r2_score(y_test, y_pred),6))
    print('Root Mean Squared Log Error (RMSLE):', round(np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),3))
    
    # Define the function to calculate the MAPE - Mean Absolute Percentage Error

    def MAPE (y_test, y_pred):
        y_test, y_pred = np.array(y_test), np.array(y_pred)
        return np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    
    # Evaluation of MAPE 

    result = MAPE(y_test, y_pred)
    print('Mean Absolute Percentage Error (MAPE):', round(result, 2), '%')
    
    # Calculate Adjusted R squared values 

    r_squared = round(metrics.r2_score(y_test, y_pred),6)
    adjusted_r_squared = round(1 - (1-r_squared)*(len(y)-1)/(len(y)-x.shape[1]-1),6)
    print('Adj R Square: ', adjusted_r_squared)
    print('------------------------------------------------------------------------------------------------------------')
    #-------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'Mean_Absolute_Error_MAE' : metrics.mean_absolute_error(y_test, y_pred),
               'Adj_R_Square' : adjusted_r_squared,
               'Root_Mean_Squared_Error_RMSE' : np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
               'Mean_Absolute_Percentage_Error_MAPE' : result,
               'Mean_Squared_Error_MSE' : metrics.mean_squared_error(y_test, y_pred),
               'Root_Mean_Squared_Log_Error_RMSLE': np.log(np.sqrt(metrics.mean_squared_error(y_test, y_pred))),
               'R2_score' : metrics.r2_score(y_test, y_pred)}
    #RGRResults = RGRResults.append(new_row, ignore_index=True)
    #-------------------------------------------------------------------------------------------
# Out:
# Model Name:  LinearRegression()
# Mean Absolute Error (MAE): 1.5
# Mean Squared Error (MSE): 3.029
# Root Mean Squared Error (RMSE): 1.74
# R2_score: -0.019517
# Root Mean Squared Log Error (RMSLE): 0.554
# Mean Absolute Percentage Error (MAPE): 24.34 %
# Adj R Square:  -0.035058
# ------------------------------------------------------------------------------------------------------------
# Model Name:  DecisionTreeRegressor()
# Mean Absolute Error (MAE): 2.019
# Mean Squared Error (MSE): 5.805
# Root Mean Squared Error (RMSE): 2.409
# R2_score: -0.953528
# Root Mean Squared Log Error (RMSLE): 0.879
# Mean Absolute Percentage Error (MAPE): 31.6 %
# Adj R Square:  -0.983307
# ------------------------------------------------------------------------------------------------------------
# Model Name:  RandomForestRegressor()
# Mean Absolute Error (MAE): 1.549
# Mean Squared Error (MSE): 3.288
# Root Mean Squared Error (RMSE): 1.813
# R2_score: -0.106469
# ...

# %%
#display all the result file

RGRResults.head(10)
# Out:
# Empty DataFrame
# Columns: [Model Name, Mean_Absolute_Error_MAE, Adj_R_Square, Root_Mean_Squared_Error_RMSE, Mean_Absolute_Percentage_Error_MAPE, Mean_Squared_Error_MSE, Root_Mean_Squared_Log_Error_RMSLE, R2_score]
# Index: []

# %%
#predect the value with ET algorithm

y_predBRR=ModelBRR.predict(x_test)

# %%
# display the final results

results=pd.DataFrame({'Rating_A':y_test,'Rating_P':y_predBRR})

#merge two dataframes on index of both the dataframes

results_final=sms_bk.merge(results,left_index=True,right_index=True)

# Display the sample 5 records

results_final.sample(5)
# Out:
#      Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 371       1     0              1       0             1       60.96         2
# 827       0     2              0       1             1       41.28         3
# 717       0     2              0       1             0       11.94         3
# 613       2     1              0       1             5       80.93         1
# 907       1     0              1       0             3       82.88         5
#
#       Tax 5%     Total  Date  Time  Payment    cogs  gross margin percentage  \
# 371   6.0960  128.0160    17   443        1  121.92                 4.761905
# 827   6.1920  130.0320    77   398        1  123.84                 4.761905
# 717   1.7910   37.6110    10   131        1   35.82                 4.761905
# 613   4.0465   84.9765    10   289        1   80.93                 4.761905
# 907  20.7200  435.1200    75   193        1  414.40                 4.761905
#
# ...

# %%
# Calculate the %of Error

results_final['%Error'] = round(((results_final['Rating_A']-results_final['Rating_P'])/results_final['Rating_A'])*100,3)

# %%
# display the results
# Display the 5 samples

results_final.sample(5)
# Out:
#      Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 678       2     1              1       1             3       58.95        10
# 76        2     1              0       1             1       49.04         9
# 380       0     2              0       1             5       82.33         4
# 995       2     1              1       1             3       40.35         1
# 603       1     0              1       0             5       54.51         6
#
#       Tax 5%     Total  Date  Time  Payment    cogs  gross margin percentage  \
# 678  29.4750  618.9750    56   207        2  589.50                 4.761905
# 76   22.0680  463.4280    30   201        1  441.36                 4.761905
# 380  16.4660  345.7860     2    29        1  329.32                 4.761905
# 995   2.0175   42.3675    21   174        2   40.35                 4.761905
# 603  16.3530  343.4130    67   182        2  327.06                 4.761905
#
# ...
